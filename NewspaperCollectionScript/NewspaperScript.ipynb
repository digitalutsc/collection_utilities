# %% [markdown]
# # Image Collection Script for Google News Archive
#
# This script was developed by the University of Toronto Scarborough's Digital Scholarship Unit to collect early Canadian newspapers from the depracted Google News Archive.
#
# ## How to use it
# Simply use the function 'get_newspapers()' which takes four arguments: The URL to the archive, the start date, end date, and name of output folder. For example, to run the script on the Halifax Gazette from January 1st 1752 to January 1st 1760 you would run:
# ```
# get_newspapers("https://news.google.com/newspapers?nid=4p3FJGzxjgAC&dat=17520323&b_mode=2&hl=en",
#                 17520101,
#                 17600101,
#                 'HalifaxGazette')
# ```
# The dates are in the form **YearMonthDay**. The output images would be in the folder called 'HalifaxGazette', which would have all of the pages seperated into folders, where one folder is one issue. These folders and images are named with the PID  given by the Google Archive.
#
# The OCR data will be found in the folder HalifaxGazetre_ocr.
#
# ### How long does the script take to run?
# It greatly depends on the range of years and newspaper, but in general an average issue takes around 20 minutes. As you can imagine, running the script on large collections can take several days. For this reason, if you stop the script and resume it, it will pick up where it left off so that you don't lose all of your progress.
#
# ## How does it work?
# The script has two main parts - getting the images and then processing them. Google News Archive hosts high definition images of newspapers; however, they are composed of several smaller images which cannot be easily webscraped. To get these smaller images, the page id's and issue id's are scraped and then used to create a link which the smaller images are located at. This is handled by the function get_template_img_urls().
#
# The second part of the script uses Python Image Library to put the smaller images together into a larger HD image. This is handled by the function create_newspaper().
#
# Finally, the Google Vision API is used to collect OCR data on the collected images. This is done with the get_ocr_data() function.
#
# ### Notes on future use/potential errors
# Due to the nature of how Google has structured there images, there is a good chance that running this script on some collections will print out: **'Warning! Image cannot be proccessed, unknown pattern'**. This means the image has an unfamilair number of smaller images which composes it. To fix this, you can simply add a new ```elif``` which builds the image. **You can see this in the example case at the bottom of save_h_imgs()**. Any image which cannot be put together will be written to the incompleted_images.txt file.
#
# Furthermore, **there is a chance that images are put together improperly**. This can happen because some images in different collections are put together in different orders, depending on the shape of the image.
#
# For example, in one newspaper an image may be made of 54 smaller images, with the large image being 6 images wide and 9 images tall. However, in another newspaper, an image may also have 54 smaller images but be 9 wide and 6 tall. At the moment, there is no way to fix this aside from going into the script and rearraning the pattern to suite the current newspaper. Hopefully, a solution can someday be used to give the script information as to the exact pattern the image has.

# %%
# Import statements 
import requests
import time
import ast
import random
import json
import os
import sys
import re
import io

from google.cloud import vision
from google.cloud.vision import types
from google.protobuf.json_format import MessageToDict
from bs4 import BeautifulSoup
import os.path
from os import path

import numpy as np
import PIL
from PIL import Image

client = vision.ImageAnnotatorClient()

# %%
def slice_url(url: str) -> str:
    """ Returns a list composed of the first
    half of the given url, behind the date, and 
    the second half of the url following the 
    date. """
    
    # Get indexes of halves
    i = url.find('dat=')
    j = url.find('&', i) 
    
    # Slice string
    half1 = url[:i+4]
    half2 = url[j:]
    
    return [half1, half2]

# %%
def remove_duplicates(str_list: list) -> list:
    """ Returns a list containing no duplicate
    elements, given str_list. """
    
    ret_list = []
    
    # Iterate through items in str_list
    for item in str_list:
        # Check if item has been already seen
        if item not in ret_list:
            # If not, add to new list.
            ret_list.append(item)
            
    # Return list with no duplicates
    return ret_list

# %%
# Function takes in list of hrefs to pages and gets page IDs
def get_page_ids(href_list: list) -> list:
    """ Returns a list of lists, each with the PIDs
    of images located on a given news issue, given
    a list of links to the pages. """
    
    ret_list = []
    
    # Iterate through the list of links
    for page in href_list:
        
        # Create a list for the PIDs
        temp_list = []
        
        # Send request at random times
        n = random.randint(6, 10)
        time.sleep(n)
        result = requests.get(page)
        
        # Get content from beautiful soup
        if result.status_code == 200:
            soup = BeautifulSoup(result.content, "html.parser")

        # Get the relevant portion of the page source
        data = soup.find_all('script')
        script_text = str(data[-1])
        
        # Use regex to find all pids in source
        pid_list = [m.start() for m in re.finditer('"pid":"', script_text)]

        # Go through pids and edit them for link
        for pid in pid_list:
            j = script_text.find(",", pid)
            i = script_text.find('",', pid)
            pid_num = script_text[pid+7:j] + '%2C' + script_text[j+1:i]
            temp_list.append(pid_num)
        
        # Append to list to be returned
        ret_list.append(remove_duplicates(temp_list))
        
    return ret_list

# %%
# Gets href list
def get_links(url: str) -> list:
    """ Returns nested list of newspaper links
    to hrefs and image links located at url to
    google news archive. """
    
    page = url
    
    # Get request from url
    n = random.randint(6, 10)
    time.sleep(n)
    result = requests.get(page)
    
    print('[attemping to reach source code at:' + url + ']')
    print(str(result))
    
    # Check for non-200 status code
    if result.status_code == 200:
        print("[source code found.]")
        soup = BeautifulSoup(result.content, "html.parser")
    else:
        print("[source code not found.]")
        return [[],[]]

    # Get needed parts of source code
    data = soup.find_all('script')
    script_text = str(data[2])

    # Get required portion of source code as list
    i = script_text.find('summary_data')
    j = script_text.rfind(']')
    script_str = script_text[i+14:j+1]
    news_list = ast.literal_eval(script_str) 

    # Initiate lists to collect links
    ret_list = []
    href_list = []
    img_list = []
    
    # Iterate through 
    for year in news_list:
        # Check if editions exist for this year
        if 'editions' in year:
            year_list = year['editions']
            # Go through editions and get image and href link
            for edition in year_list:
                img_list.append(edition['img_url'])
                href_list.append(edition['href_url'])
    
    # Add these lists to returned list
    ret_list.append(href_list)
    ret_list.append(img_list)
    
    return ret_list

# %%
def get_nested_link_list(start_date: int, end_date: int, url: str) -> list:
    """ Returns nested list of newspaper links
    to hrefs and image linkes from url to google
    news archive. from end_date to start_date"""
    
    # Slice and get the important parts of URL
    sliced_url = slice_url(url)
    
    url1 = sliced_url[0]
    url2 = sliced_url[1]
    
    href_dict = {}
    image_dict = {}

    # Go through months of archive
    i = start_date
    while(i < end_date):
        # Get links from url at particular date, both at yearly mark and
        # after sixth months
        list_of_links1 = get_links(url1 + str(i) + url2)
        list_of_links2 = get_links(url1 + str(i+600) + url2)
        
        # Add the links together
        list_of_hrefs = list_of_links1[0] + list_of_links2[0]
        list_of_imgs = list_of_links1[1] + list_of_links2[1]
        
        list_of_links = [list_of_hrefs, list_of_imgs]
        
        # Add the links to a dictionary so that there are no duplicates
        for href in list_of_links[0]:
            href_dict[href] = 1
        for img in list_of_links[1]:
            image_dict[img] = 1

        # Forward date by a year
        i+=10000
        
    # Convert keys to list and return
    final_href_list = list(href_dict.keys())
    final_image_list = list(image_dict.keys())

    return [final_href_list, final_image_list]

# %%
def get_news_id(url: str) -> str:
    """ Return the id from the url to
    an image link for the newspaper."""

    # Isolate and return important part of link
    i = url.find("?id=")
    j = url.find("&pg=")
    return url[i+4:j+4]

# %%
def write_list_to_file(l: str, name: str) -> None:
    """ Writes each item in the list
    to a row in the text file. """
    
    with open(name, "a") as f:
        for item in l:
            f.write("%s\n" % item)

# %%
def get_template_img_urls(url: str, start_date: int, end_date: int) -> list:
    """ Returns array of template urls that point to 
    images which make up newspapers."""
        
    # Get list of links to pages where newspapers and images are located
    list_of_links = get_nested_link_list(start_date, end_date, url)
    # Get list of PIDs for each page in newspaper
    pid_list = get_page_ids(list_of_links[0])

    final_array = []

    # Iterate through the links to thumbnails
    for i in range(len(list_of_links[1])):
        link = list_of_links[1][i]
        # Loop through the pids for this particular image
        for j in range(len(pid_list[i])):
            url1 = "https://news.google.com/newspapers?id=" + get_news_id(link) + pid_list[i][j] + "&img=1&hl=en&zoom=1&tid="
            final_array.append(url1)

    return final_array

# %%
def get_file(image_url: str) -> str:
    """ Returns name of image, downloaded 
    from image_url"""
    
    # Request image from URL
    n = random.randint(4, 9)
    time.sleep(n)
    img_data = requests.get(image_url).content
    
    # Get image as string
    data_str = str(img_data)
    
    # Check if image exists (it will send back a gif if not image)
    if data_str.startswith("b'GIF"):
        return ""
    
    else:
        # If image exists, download it to memory.
        with open("small_output/" + image_url[-5:] + "small_image.jpg", "wb") as handler:
            handler.write(img_data)
        return "small_output/" + image_url[-5:] + "small_image.jpg"

# %%
def generate_images(url: str) -> list:
    """ Returns a list containing the names of 
    downloaded images making up image found at url.
    """
    
    # Initiate list to be returned 
    all_imgs = []
    
    # Set flag and iterator variable
    found_end = False
    i = 0
    
    # Collect images from link while images exist
    while found_end == False and i < 150:
        # Iterate through the image links, downloading them
        send_url = url + str(i)
        ret = get_file(send_url)
        # If no file found set flag to True
        if ret == "":
            found_end = True
        # Otherwise add the name of the image to the list
        else:
            found_end = False
            all_imgs.append(ret)
        i+=1
        
    # Return list of names
    return all_imgs

# %%
def save_v_img(n: int, num: int, url: str):
    """ Given integer n, saves files named in the format
    'h' + n + '.jpg' as a large image stacked together. Named
    with num. """
    
    # Loop through partial images
    saved_obj_list = []
    for i in range(1, n):
        im = Image.open("h" + str(i) + ".jpg")
        saved_obj_list.append(im)

    # Get name of file using url
    full_pid = get_news_id(url)
    j = full_pid.find('&')
    issue_num = full_pid[:j]
    
    k = url.find("%2C")
    l = url.rfind("&img=")
    page_num = url[k+3:l]
    
    if os.path.exists('image_output/' + issue_num) == False:
        os.mkdir('image_output/' + issue_num)
    
    name = 'image_output/' + issue_num + '/' + page_num + '.jpg'
    print("[Image saved as: " + name + "]")
    
    # Save with name
    get_concat_h_multi_blank(saved_obj_list, 'v').save(name)

# %%
def get_concat_h_blank(im1, im2, color=(0, 0, 0)):
    """ Merges images im1 and im2 horizontally.
    Sourced from PIL documentation. """
    
    dst = Image.new('RGB', (im1.width + im2.width, max(im1.height, im2.height)), color)
    dst.paste(im1, (0, 0))
    dst.paste(im2, (im1.width, 0))
    
    # Returns image as object
    return dst

def get_concat_v_blank(im1, im2, color=(0, 0, 0)):
    """ Merges images im1 and im2 vertically.
    Sourced from PIL documentation. """
    
    dst = Image.new('RGB', (max(im1.width, im2.width), im1.height + im2.height), color)
    dst.paste(im1, (0, 0))
    dst.paste(im2, (0, im1.height))
    
    # Returns image as object
    return dst

def get_concat_h_multi_blank(im_list: list, dr: str):
    """ Merges multiple images contained in 
    im_list vertically. Sourced from PIL 
    documentation. """
    
    _im = im_list.pop(0)
    
    # Loop through images and concatenate
    for im in im_list:
        if dr == "h":
            _im = get_concat_h_blank(_im, im)
        else:
            _im = get_concat_v_blank(_im, im)
    return _im

# %%
def save_h_imgs(l: list, n: int, img_url: str) -> None:
    """ Merges images from l in pattern which
    creates large image for Google News Archive
    images."""
    
    list_len = len(l)
    
    if list_len == 35:
        get_concat_h_multi_blank([l[0], l[1], l[2], l[9], l[10]], 'h').save('h1.jpg')
        get_concat_h_multi_blank([l[3], l[4], l[5], l[11], l[12]], 'h').save('h2.jpg')
        get_concat_h_multi_blank([l[6], l[7], l[8], l[13], l[14]], 'h').save('h3.jpg')
        get_concat_h_multi_blank([l[15], l[16], l[17], l[24], l[25]], 'h').save('h4.jpg')
        get_concat_h_multi_blank([l[18], l[19], l[20], l[26], l[27]], 'h').save('h5.jpg')
        get_concat_h_multi_blank([l[21], l[22], l[23], l[28], l[29]], 'h').save('h6.jpg')  
        get_concat_h_multi_blank([l[30], l[31], l[32], l[33], l[34]], 'h').save('h7.jpg')
        
        save_v_img(8, n, img_url)
        
    elif list_len == 48:
        get_concat_h_multi_blank([l[0], l[1], l[2], l[9], l[10], l[11], l[18], l[19]], 'h').save('h1.jpg')
        get_concat_h_multi_blank([l[3], l[4], l[5], l[12], l[13], l[14], l[20], l[21]], 'h').save('h2.jpg')
        get_concat_h_multi_blank([l[6], l[7], l[8], l[15], l[16], l[17], l[22], l[23]], 'h').save('h3.jpg')
        get_concat_h_multi_blank([l[24], l[25], l[26], l[33], l[34], l[35], l[42], l[43]], 'h').save('h4.jpg')
        get_concat_h_multi_blank([l[27], l[28], l[29], l[36], l[37], l[38], l[44], l[45]], 'h').save('h5.jpg')  
        get_concat_h_multi_blank([l[30], l[31], l[32], l[39], l[40], l[41], l[46], l[47]], 'h').save('h6.jpg') 
   
        save_v_img(7, n, img_url)
    
    elif list_len == 54:
        get_concat_h_multi_blank([l[0], l[1], l[2], l[9], l[10], l[11], l[18], l[19], l[20]], 'h').save('h1.jpg')
        get_concat_h_multi_blank([l[3], l[4], l[5], l[12], l[13], l[14], l[21], l[22], l[23]], 'h').save('h2.jpg')
        get_concat_h_multi_blank([l[6], l[7], l[8], l[15], l[16], l[17], l[24], l[25], l[26]],  'h').save('h3.jpg')
        get_concat_h_multi_blank([l[27], l[28], l[29], l[36], l[37], l[38], l[45], l[46], l[47]], 'h').save('h4.jpg')
        get_concat_h_multi_blank([l[30], l[31], l[32], l[39], l[40], l[41], l[48], l[49], l[50]], 'h').save('h5.jpg')  
        get_concat_h_multi_blank([l[33], l[34], l[35], l[42], l[43], l[44], l[51], l[52], l[53]], 'h').save('h6.jpg') 
        
        save_v_img(7, n, img_url)
    
    elif list_len == 45:
        get_concat_h_multi_blank([l[0], l[1], l[2], l[9], l[10]], 'h').save('h1.jpg')
        get_concat_h_multi_blank([l[3], l[4], l[5], l[11], l[12]], 'h').save('h2.jpg')
        get_concat_h_multi_blank([l[6], l[7], l[8], l[13], l[14]], 'h').save('h3.jpg')
        get_concat_h_multi_blank([l[15], l[16], l[17], l[24], l[25]], 'h').save('h4.jpg')
        get_concat_h_multi_blank([l[18], l[19], l[20], l[26], l[27]], 'h').save('h5.jpg')
        get_concat_h_multi_blank([l[21], l[22], l[23], l[28], l[29]], 'h').save('h6.jpg')  
        get_concat_h_multi_blank([l[30], l[31], l[32], l[39], l[40]], 'h').save('h7.jpg')
        get_concat_h_multi_blank([l[33], l[34], l[35], l[41], l[42]], 'h').save('h8.jpg')
        get_concat_h_multi_blank([l[36], l[37], l[38], l[43], l[44]], 'h').save('h9.jpg')
        
        save_v_img(10, n, img_url)
    
    elif list_len == 25:
        get_concat_h_multi_blank([l[0], l[1], l[2], l[9], l[10]], 'h').save('h1.jpg')
        get_concat_h_multi_blank([l[3], l[4], l[5], l[11], l[12]], 'h').save('h2.jpg')
        get_concat_h_multi_blank([l[6], l[7], l[8], l[13], l[14]], 'h').save('h3.jpg')
        get_concat_h_multi_blank([l[15], l[16], l[17], l[21], l[22]], 'h').save('h4.jpg')
        get_concat_h_multi_blank([l[18], l[19], l[20], l[23], l[24]], 'h').save('h5.jpg')
        
        save_v_img(6, n, img_url)
    
    elif list_len == 56:
        get_concat_h_multi_blank([l[0], l[1], l[2], l[9], l[10], l[11], l[18]], 'h').save('h1.jpg')
        get_concat_h_multi_blank([l[3], l[4], l[5], l[12], l[13], l[14], l[19]], 'h').save('h2.jpg')
        get_concat_h_multi_blank([l[6], l[7], l[8], l[15], l[16], l[17], l[20]], 'h').save('h3.jpg')
        get_concat_h_multi_blank([l[21], l[22], l[23], l[30], l[31], l[32], l[39]], 'h').save('h4.jpg')
        get_concat_h_multi_blank([l[24], l[25], l[26], l[33], l[34], l[35], l[40]], 'h').save('h5.jpg')
        get_concat_h_multi_blank([l[27], l[28], l[29], l[36], l[37], l[38], l[41]], 'h').save('h6.jpg')
        get_concat_h_multi_blank([l[42], l[43], l[44], l[48], l[49], l[50], l[54]], 'h').save('h7.jpg')
        get_concat_h_multi_blank([l[45], l[46], l[47], l[51], l[52], l[53], l[55]], 'h').save('h8.jpg') 
        
        save_v_img(9, n, img_url)
    
    elif list_len == 63:
        get_concat_h_multi_blank([l[0], l[1], l[2], l[9], l[10], l[11], l[18], l[19], l[20]], 'h').save('h1.jpg')
        get_concat_h_multi_blank([l[3], l[4], l[5], l[12], l[13], l[14], l[21], l[22], l[23]], 'h').save('h2.jpg')
        get_concat_h_multi_blank([l[6], l[7], l[8], l[15], l[16], l[17], l[24], l[25], l[26]], 'h').save('h3.jpg')
        get_concat_h_multi_blank([l[27], l[28], l[29], l[36], l[37], l[38], l[45], l[46], l[47]], 'h').save('h4.jpg')
        get_concat_h_multi_blank([l[30], l[31], l[32], l[39], l[40], l[41], l[48], l[49], l[50]], 'h').save('h5.jpg')
        get_concat_h_multi_blank([l[33], l[34], l[35], l[42], l[43], l[44], l[51], l[52], l[53]], 'h').save('h6.jpg')
        get_concat_h_multi_blank([l[54], l[55], l[56], l[57], l[58], l[59], l[60], l[61], l[62]], 'h').save('h7.jpg')

        save_v_img(8, n, img_url)

    elif list_len == 42:
        get_concat_h_multi_blank([l[0], l[1], l[2], l[9], l[10], l[11], l[18]], 'h').save('h1.jpg')
        get_concat_h_multi_blank([l[3], l[4], l[5], l[12], l[13], l[14], l[19]], 'h').save('h2.jpg')
        get_concat_h_multi_blank([l[6], l[7], l[8], l[15], l[16], l[17], l[20]], 'h').save('h3.jpg')
        get_concat_h_multi_blank([l[21], l[22], l[23], l[30], l[31], l[32], l[39]], 'h').save('h4.jpg')  
        get_concat_h_multi_blank([l[24], l[25], l[26], l[33], l[34], l[35], l[40]], 'h').save('h5.jpg') 
        get_concat_h_multi_blank([l[27], l[28], l[29], l[36], l[37], l[38], l[41]], 'h').save('h6.jpg')
        
        save_v_img(7, n, img_url)
    
    elif list_len == 36:
        get_concat_h_multi_blank([l[0], l[1], l[2], l[9], l[10], l[11]], 'h').save('h1.jpg')
        get_concat_h_multi_blank([l[3], l[4], l[5], l[12], l[13], l[14]], 'h').save('h2.jpg')
        get_concat_h_multi_blank([l[6], l[7], l[8], l[15], l[16], l[17]], 'h').save('h3.jpg')
        get_concat_h_multi_blank([l[18], l[19], l[20], l[27], l[28], l[29]], 'h').save('h4.jpg')
        get_concat_h_multi_blank([l[21], l[22], l[23], l[30], l[31], l[32]], 'h').save('h5.jpg')  
        get_concat_h_multi_blank([l[24], l[25], l[26], l[33], l[34], l[35]], 'h').save('h6.jpg')
        
        save_v_img(7, n, img_url)
    
    elif list_len == 49:
        get_concat_h_multi_blank([l[0], l[1], l[2], l[9], l[10], l[11], l[18]], 'h').save('h1.jpg')
        get_concat_h_multi_blank([l[3], l[4], l[5], l[12], l[13], l[14], l[19]], 'h').save('h2.jpg')
        get_concat_h_multi_blank([l[6], l[7], l[8], l[15], l[16], l[17], l[20]], 'h').save('h3.jpg')
        get_concat_h_multi_blank([l[21], l[22], l[23], l[30], l[31], l[32], l[39]], 'h').save('h4.jpg')
        get_concat_h_multi_blank([l[24], l[25], l[26], l[33], l[34], l[35], l[40]], 'h').save('h5.jpg')  
        get_concat_h_multi_blank([l[27], l[28], l[29], l[36], l[37], l[38], l[41]], 'h').save('h6.jpg') 
        get_concat_h_multi_blank([l[42], l[43], l[44], l[45], l[46], l[47], l[48]], 'h').save('h7.jpg')
        
        save_v_img(8, n, img_url)

    elif list_len == 24:
        get_concat_h_multi_blank([l[0], l[1], l[2], l[9]], 'h').save('h1.jpg')
        get_concat_h_multi_blank([l[3], l[4], l[5], l[10]], 'h').save('h2.jpg')
        get_concat_h_multi_blank([l[6], l[7], l[8], l[11]], 'h').save('h3.jpg')
        get_concat_h_multi_blank([l[12], l[13], l[14], l[21]], 'h').save('h4.jpg')
        get_concat_h_multi_blank([l[15], l[16], l[17], l[22]], 'h').save('h5.jpg')
        get_concat_h_multi_blank([l[18], l[19], l[20], l[23]], 'h').save('h6.jpg')
        
        save_v_img(7, n, img_url)
    
    elif list_len == 20:
        get_concat_h_multi_blank([l[0], l[1], l[2], l[9]], 'h').save('h1.jpg')
        get_concat_h_multi_blank([l[3], l[4], l[5], l[10]], 'h').save('h2.jpg')
        get_concat_h_multi_blank([l[6], l[7], l[8], l[11]], 'h').save('h3.jpg')
        get_concat_h_multi_blank([l[12], l[13], l[14], l[18]], 'h').save('h4.jpg')
        get_concat_h_multi_blank([l[15], l[16], l[17], l[19]], 'h').save('h5.jpg')
        
        save_v_img(6, n, img_url)

    elif list_len == 28:
        get_concat_h_multi_blank([l[0], l[1], l[2], l[9]], 'h').save('h1.jpg')
        get_concat_h_multi_blank([l[3], l[4], l[5], l[10]], 'h').save('h2.jpg')
        get_concat_h_multi_blank([l[6], l[7], l[8], l[11]], 'h').save('h3.jpg')
        get_concat_h_multi_blank([l[12], l[13], l[14], l[21]], 'h').save('h4.jpg')
        get_concat_h_multi_blank([l[15], l[16], l[17], l[22]], 'h').save('h5.jpg')
        get_concat_h_multi_blank([l[18], l[19], l[20], l[23]], 'h').save('h6.jpg')
        get_concat_h_multi_blank([l[24], l[25], l[26], l[27]], 'h').save('h7.jpg')
        
        save_v_img(8, n, img_url)

    elif list_len == 15:
        get_concat_h_multi_blank([l[0], l[1], l[2]], 'h').save('h1.jpg')
        get_concat_h_multi_blank([l[3], l[4], l[5]], 'h').save('h2.jpg')
        get_concat_h_multi_blank([l[6], l[7], l[8]], 'h').save('h3.jpg')
        get_concat_h_multi_blank([l[9], l[10], l[11]], 'h').save('h4.jpg')
        get_concat_h_multi_blank([l[12], l[13], l[14]], 'h').save('h5.jpg')
        
        save_v_img(6, n, img_url)
        
    elif list_len == 12:
        get_concat_h_multi_blank([l[0], l[1], l[2]], 'h').save('h1.jpg')
        get_concat_h_multi_blank([l[3], l[4], l[5]], 'h').save('h2.jpg')
        get_concat_h_multi_blank([l[6], l[7], l[8]], 'h').save('h3.jpg')
        get_concat_h_multi_blank([l[9], l[10], l[11]], 'h').save('h4.jpg')
        
        save_v_img(5, n, img_url)

    elif list_len == 40:
        get_concat_h_multi_blank([l[0], l[1], l[2], l[9], l[10]], 'h').save('h1.jpg')
        get_concat_h_multi_blank([l[3], l[4], l[5], l[11], l[12]], 'h').save('h2.jpg')
        get_concat_h_multi_blank([l[6], l[7], l[8], l[13], l[14]], 'h').save('h3.jpg')
        get_concat_h_multi_blank([l[15], l[16], l[17], l[24], l[25]], 'h').save('h4.jpg')
        get_concat_h_multi_blank([l[18], l[19], l[20], l[26], l[27]], 'h').save('h5.jpg')
        get_concat_h_multi_blank([l[21], l[22], l[23], l[28], l[29]], 'h').save('h6.jpg')  
        get_concat_h_multi_blank([l[30], l[31], l[32], l[36], l[37]], 'h').save('h7.jpg') 
        get_concat_h_multi_blank([l[33], l[34], l[35], l[38], l[39]], 'h').save('h8.jpg')
        
        save_v_img(9, n, img_url)

    elif list_len == 30:
        get_concat_h_multi_blank([l[0], l[1], l[2], l[9], l[10]], 'h').save('h1.jpg')
        get_concat_h_multi_blank([l[3], l[4], l[5], l[11], l[12]], 'h').save('h2.jpg')
        get_concat_h_multi_blank([l[6], l[7], l[8], l[13], l[14]], 'h').save('h3.jpg')
        get_concat_h_multi_blank([l[15], l[16], l[17], l[24], l[25]], 'h').save('h4.jpg')
        get_concat_h_multi_blank([l[18], l[19], l[20], l[26], l[27]], 'h').save('h5.jpg')
        get_concat_h_multi_blank([l[21], l[22], l[23], l[28], l[29]], 'h').save('h6.jpg')
        
        save_v_img(7, n, img_url)
        
#     elif list_len == ex_num:
#         get_concat_h_multi_blank([l[], l[], l[], l[], l[] .... ], 'h').save('h1.jpg')
#         get_concat_h_multi_blank([l[], l[], l[], l[], l[] .... ], 'h').save('h2.jpg')
#         ....
#         ....
#         ....
#         get_concat_h_multi_blank([l[], l[], l[], l[], l[] .... ], 'h').save('hx.jpg')
        
#         save_v_img(x+1, n, img_url) Where x is the number of function calls above.
    
    else:
        print("Warning! Image is not of known size.")
        with open("incompleted_images.txt", "a") as g:
            g.write("%s\n" % img_url)

# %%
def create_newspaper(n: int, img_url: str):
    """ Given img_url, generates a newspaper
    from images collected from that url. """
    
    # Generate the images composing larger image
    img_list = generate_images(img_url)
    obj_list = []
    print("Number of images: " + str(len(img_list)))
    
    # Use PIL and make each an image object
    for file in img_list:
        im = Image.open(file)
        obj_list.append(im)
    
    # Determine what pattern the images go together with
    list_len = len(img_list)
    
    # Put together each image appropriately
    save_h_imgs(obj_list, n, img_url)
    
    # Remove images from memory
    for item in img_list:
        os.remove(item)

# %%
def get_ocr_data(url: str) -> None:
    
    full_pid = get_news_id(url)
    j = full_pid.find('&')
    issue_num = full_pid[:j]
    
    k = url.find("%2C")
    l = url.rfind("&img=")
    page_num = url[k+3:l]
    
    file_name = issue_num + '/' + page_num
    
    if path.exists('image_output/' + file_name + '.jpg'):
        with io.open('image_output/' + file_name + '.jpg', 'rb') as image_file:
            content = image_file.read()

        print("[Running OCR]")

        image = vision.types.Image(content = content)
        response = client.text_detection(image = image)
        texts = response.text_annotations

        # Convert the response to dictionary
        response = MessageToDict(response)

        # Convert to json
        j_file = 'ocr_output/' + issue_num + '-' + page_num + "_annotated_ocr.json" 
        out_file = open(j_file, "w")  
        json.dump(response, out_file)     
        out_file.close()
        print("[Saved as: " + j_file + "]")

        # Convert to .txt
        if len(texts) != 0:
            text = ('\n"{}"'.format(texts[0].description))
        else:
            text = ""
        o_file = 'ocr_output/' + issue_num + '-' + page_num + "_OCR.txt"
        file = open(o_file,"w") 
        file.write(text)
        file.close()
        print("[Saved as: " + o_file + "]\n")

# %%
def get_newspapers(url: str, start_date: int, end_date: int, folder_name: str) -> None:
    """ Generates newspapers as jpgs located
    at the url on google's newspaper archives."""
    
    # Get list of links which point to images
    list_of_imgs = get_template_img_urls(url, start_date, end_date)
    print("Number of images to be processed: " + str(len(list_of_imgs)))

    start = sum(1 for line in open('completed_images.txt'))
    print("Starting at: " + str(start))
    # Loop through each template image link
    for i in range(start, len(list_of_imgs)):
        print(str(i) + " [Building images located at: " + list_of_imgs[i] + ']')

        # Create newspaper image from link
        create_newspaper(i, list_of_imgs[i])

        # Collect OCR data
        get_ocr_data(list_of_imgs[i])

        # Log completed image
        with open("completed_images.txt", "a") as g:
            g.write("%s\n" % list_of_imgs[i])
        
    # Label folder and create new folders
    os.rename('image_output', folder_name)
    os.rename('ocr_output', folder_name + "_ocr")
    
    os.mkdir('image_output')
    os.mkdir('ocr_output')
    
    open('completed_images.txt', 'w').close()

# %%
# Run this first - St.johns Royal Gazette
# get_newspapers("https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17920629&b_mode=2&hl=en",
#                17840101,
#                17990901,
#                'RoyalStJohnGazette')

# Run this second - Quebec Gazette
# get_newspapers("https://news.google.com/newspapers?nid=F_tUKv7nyWgC&dat=17750518&b_mode=2&hl=en",
#                 17550101,
#                 17650201,
#                 'QuebecGazette')
# Out:
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17840101&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17840701&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17850101&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17850701&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17860101&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17860701&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17870101&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17870701&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17880101&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17880701&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17890101&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17890701&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17900101&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17900701&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17910101&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17910701&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17920101&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17920701&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17930101&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17930701&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17940101&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17940701&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17950101&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17950701&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17960101&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17960701&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17970101&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17970701&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17980101&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17980701&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17990101&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# [attemping to reach source code at:https://news.google.com/newspapers?nid=QhmGFXoqNHAC&dat=17990701&b_mode=2&hl=en]
# <Response [200]>
# [source code found.]
# Number of images to be processed: 516
# Starting at: 61
# 61 [Building images located at: https://news.google.com/newspapers?id=fN9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C622910&img=1&hl=en&zoom=1&tid=]
# Number of images: 48
# [Image saved as: image_output/fN9MAAAAIBAJ/622910.jpg]
# [Running OCR]
# [Saved as: ocr_output/fN9MAAAAIBAJ-622910_annotated_ocr.json]
# [Saved as: ocr_output/fN9MAAAAIBAJ-622910_OCR.txt]
#
# 62 [Building images located at: https://news.google.com/newspapers?id=fd9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=320%2C633534&img=1&hl=en&zoom=1&tid=]
# Number of images: 54
# [Image saved as: image_output/fd9MAAAAIBAJ/633534.jpg]
# [Running OCR]
# [Saved as: ocr_output/fd9MAAAAIBAJ-633534_annotated_ocr.json]
# [Saved as: ocr_output/fd9MAAAAIBAJ-633534_OCR.txt]
#
# 63 [Building images located at: https://news.google.com/newspapers?id=fd9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=320%2C644414&img=1&hl=en&zoom=1&tid=]
# Number of images: 54
# [Image saved as: image_output
9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C907373&img=1&hl=en&zoom=1&tid=]
# Number of images: 54
# [Image saved as: image_output/gt9MAAAAIBAJ/907373.jpg]
# [Running OCR]
# [Saved as: ocr_output/gt9MAAAAIBAJ-907373_annotated_ocr.json]
# [Saved as: ocr_output/gt9MAAAAIBAJ-907373_OCR.txt]
#
# 85 [Building images located at: https://news.google.com/newspapers?id=gt9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=0%2C918253&img=1&hl=en&zoom=1&tid=]
# Number of images: 36
# [Image saved as: image_output/gt9MAAAAIBAJ/918253.jpg]
# [Running OCR]
# [Saved as: ocr_output/gt9MAAAAIBAJ-918253_annotated_ocr.json]
# [Saved as: ocr_output/gt9MAAAAIBAJ-918253_OCR.txt]
#
# 86 [Building images located at: https://news.google.com/newspapers?id=gt9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C927624&img=1&hl=en&zoom=1&tid=]
# Number of images: 42
# [Image saved as: image_output/gt9MAAAAIBAJ/927624.jpg]
# [Running OCR]
# [Saved as: ocr_output/gt9MAAAAIBAJ-927624_annotated_ocr.json]
# [Saved as: ocr_output/gt9MAAAAIBAJ-927624_OCR.txt]
#
# 87 [Building images located at: https://news.google.com/newspapers?id=gt9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=320%2C936205&img=1&hl=en&zoom=1&tid=]
# Number of images: 12
# [Image saved as: image_output/gt9MAAAAIBAJ/936205.jpg]
# [Running OCR]
# [Saved as: ocr_output/gt9MAAAAIBAJ-936205_annotated_ocr.json]
# [Saved as: ocr_output/gt9MAAAAIBAJ-936205_OCR.txt]
#
# 88 [Building images located at: https://news.google.com/newspapers?id=g99MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=320%2C938541&img=1&hl=en&zoom=1&tid=]
# Number of images: 42
# [Image saved as: image_output/g99MAAAAIBAJ/938541.jpg]
# [Running OCR]
# [Saved as: ocr_output/g99MAAAAIBAJ-938541_annotated_ocr.json]
# [Saved as: ocr_output/g99MAAAAIBAJ-938541_OCR.txt]
#
# 89 [Building images located at: https://news.google.com/newspapers?id=g99MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C947245&img=1&hl=en&zoom=1&tid=]
# Number of images: 54
# [Image saved as: image_output/g99MAAAAIBAJ/947245.jpg]
# [Running OCR]
# [Saved as: ocr_output/g99MAAAAIBAJ-947245_annotated_ocr.json]
# [Saved as: ocr_output/g99MAAAAIBAJ-947245_OCR.txt]
#
# 90 [Building images located at: https://news.google.com/newspapers?id=g99MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=256%2C957901&img=1&hl=en&zoom=1&tid=]
# Number of images: 48
# [Image saved as: image_output/g99MAAAAIBAJ/957901.jpg]
# [Running OCR]
# [Saved as: ocr_output/g99MAAAAIBAJ-957901_annotated_ocr.json]
# [Saved as: ocr_output/g99MAAAAIBAJ-957901_OCR.txt]
#
# 91 [Building images located at: https://news.google.com/newspapers?id=g99MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=32%2C968749&img=1&hl=en&zoom=1&tid=]
# Number of images: 54
# [Image saved as: image_output/g99MAAAAIBAJ/968749.jpg]
# [Running OCR]
# [Saved as: ocr_output/g99MAAAAIBAJ-968749_annotated_ocr.json]
# [Saved as: ocr_output/g99MAAAAIBAJ-968749_OCR.txt]
#
# 92 [Building images located at: https://news.google.com/newspapers?id=hN9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=320%2C981517&img=1&hl=en&zoom=1&tid=]
# Number of images: 96
# Warning! Image is not of known size.
# 93 [Building images located at: https://news.google.com/newspapers?id=hN9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C992493&img=1&hl=en&zoom=1&tid=]
# Number of images: 96
# Warning! Image is not of known size.
# 94 [Building images located at: https://news.google.com/newspapers?id=hN9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1003405&img=1&hl=en&zoom=1&tid=]
# Number of images: 96
# Warning! Image is not of known size.
# 95 [Building images located at: https://news.google.com/newspapers?id=hN9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1014285&img=1&hl=en&zoom=1&tid=]
# Number of images: 16
# Warning! Image is not of known size.
# 96 [Building images located at: https://news.google.com/newspapers?id=hN9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1016013&img=1&hl=en&zoom=1&tid=]
# Number of images: 80
# Warning! Image is not of known size.
# 97 [Building images located at: https://news.google.com/newspapers?id=hN9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=320%2C1025138&img=1&hl=en&zoom=1&tid=]
# Number of images: 16
# Warning! Image is not of known size.
# 98 [Building images located at: https://news.google.com/newspapers?id=hN9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=256%2C1026957&img=1&hl=en&zoom=1&tid=]
# Number of images: 80
# Warning! Image is not of known size.
# 99 [Building images located at: https://news.google.com/newspapers?id=hN9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=320%2C1036013&img=1&hl=en&zoom=1&tid=]
# Number of images: 16
# Warning! Image is not of known size.
# 100 [Building images located at: https://news.google.com/newspapers?id=hN9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1038066&img=1&hl=en&zoom=1&tid=]
# Number of images: 80
# Warning! Image is not of known size.
# 101 [Building images located at: https://news.google.com/newspapers?id=hN9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=320%2C1046994&img=1&hl=en&zoom=1&tid=]
# Number of images: 16
# Warning! Image is not of known size.
# 102 [Building images located at: https://news.google.com/newspapers?id=hN9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1049010&img=1&hl=en&zoom=1&tid=]
# Number of images: 80
# Warning! Image is not of known size.
# 103 [Building images located at: https://news.google.com/newspapers?id=hN9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=320%2C1057874&img=1&hl=en&zoom=1&tid=]
# Number of images: 16
# Warning! Image is not of known size.
# 104 [Building images located at: https://news.google.com/newspapers?id=hN9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1059698&img=1&hl=en&zoom=1&tid=]
# Number of images: 80
# Warning! Image is not of known size.
# 105 [Building images located at: https://news.google.com/newspapers?id=hN9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1068786&img=1&hl=en&zoom=1&tid=]
# Number of images: 96
# Warning! Image is not of known size.
# 106 [Building images located at: https://news.google.com/newspapers?id=hN9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1079698&img=1&hl=en&zoom=1&tid=]
# Number of images: 88
# Warning! Image is not of known size.
# 107 [Building images located at: https://news.google.com/newspapers?id=hN9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1090610&img=1&hl=en&zoom=1&tid=]
# Number of images: 88
# Warning! Image is not of known size.
# 108 [Building images located at: https://news.google.com/newspapers?id=hN9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1101303&img=1&hl=en&zoom=1&tid=]
# Number of images: 88
# Warning! Image is not of known size.
# 109 [Building images located at: https://news.google.com/newspapers?id=hN9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=256%2C1112242&img=1&hl=en&zoom=1&tid=]
# Number of images: 16
# Warning! Image is not of known size.
# 110 [Building images located at: https://news.google.com/newspapers?id=hd9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=320%2C1114071&img=1&hl=en&zoom=1&tid=]
# Number of images: 42
# [Image saved as: image_output/hd9MAAAAIBAJ/1114071.jpg]
# [Running OCR]
# [Saved as: ocr_output/hd9MAAAAIBAJ-1114071_annotated_ocr.json]
# [Saved as: ocr_output/hd9MAAAAIBAJ-1114071_OCR.txt]
#
# 111 [Building images located at: https://news.google.com/newspapers?id=hd9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1123090&img=1&hl=en&zoom=1&tid=]
# Number of images: 12
# [Image saved as: image_output/hd9MAAAAIBAJ/1123090.jpg]
# [Running OCR]
# [Saved as: ocr_output/hd9MAAAAIBAJ-1123090_annotated_ocr.json]
# [Saved as: ocr_output/hd9MAAAAIBAJ-1123090_OCR.txt]
#
# 112 [Building images located at: https://news.google.com/newspapers?id=hd9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1124919&img=1&hl=en&zoom=1&tid=]
# Number of images: 42
# [Image saved as: image_output/hd9MAAAAIBAJ/1124919.jpg]
# [Running OCR]
# [Saved as: ocr_output/hd9MAAAAIBAJ-1124919_annotated_ocr.json]
# [Saved as: ocr_output/hd9MAAAAIBAJ-1124919_OCR.txt]
#
# 113 [Building images located at: https://news.google.com/newspapers?id=hd9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=224%2C1133975&img=1&hl=en&zoom=1&tid=]
# Number of images: 12
# [Image saved as: image_output/hd9MAAAAIBAJ/1133975.jpg]
# [Running OCR]
# [Saved as: ocr_output/hd9MAAAAIBAJ-1133975_annotated_ocr.json]
# [Saved as: ocr_output/hd9MAAAAIBAJ-1133975_OCR.txt]
#
# 114 [Building images located at: https://news.google.com/newspapers?id=hd9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1135831&img=1&hl=en&zoom=1&tid=]
# Number of images: 42
# [Image saved as: image_output/hd9MAAAAIBAJ/1135831.jpg]
# [Running OCR]
# [Saved as: ocr_output/hd9MAAAAIBAJ-1135831_annotated_ocr.json]
# [Saved as: ocr_output/hd9MAAAAIBAJ-1135831_OCR.txt]
#
# 115 [Building images located at: https://news.google.com/newspapers?id=hd9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=320%2C1144951&img=1&hl=en&zoom=1&tid=]
# Number of images: 12
# [Image saved as: image_output/hd9MAAAAIBAJ/1144951.jpg]
# [Running OCR]
# [Saved as: ocr_output/hd9MAAAAIBAJ-1144951_annotated_ocr.json]
# [Saved as: ocr_output/hd9MAAAAIBAJ-1144951_OCR.txt]
#
# 116 [Building images located at: https://news.google.com/newspapers?id=hd9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=320%2C1146807&img=1&hl=en&zoom=1&tid=]
# Number of images: 42
# [Image saved as: image_output/hd9MAAAAIBAJ/1146807.jpg]
# [Running OCR]
# [Saved as: ocr_output/hd9MAAAAIBAJ-1146807_annotated_ocr.json]
# [Saved as: ocr_output/hd9MAAAAIBAJ-1146807_OCR.txt]
#
# 117 [Building images located at: https://news.google.com/newspapers?id=hd9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=320%2C1155831&img=1&hl=en&zoom=1&tid=]
# Number of images: 12
# [Image saved as: image_output/hd9MAAAAIBAJ/1155831.jpg]
# [Running OCR]
# [Saved as: ocr_output/hd9MAAAAIBAJ-1155831_annotated_ocr.json]
# [Saved as: ocr_output/hd9MAAAAIBAJ-1155831_OCR.txt]
#
# 118 [Building images located at: https://news.google.com/newspapers?id=hd9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1157687&img=1&hl=en&zoom=1&tid=]
# Number of images: 42
# [Image saved as: image_output/hd9MAAAAIBAJ/1157687.jpg]
# [Running OCR]
# [Saved as: ocr_output/hd9MAAAAIBAJ-1157687_annotated_ocr.json]
# [Saved as: ocr_output/hd9MAAAAIBAJ-1157687_OCR.txt]
#
# 119 [Building images located at: https://news.google.com/newspapers?id=hd9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=256%2C1166743&img=1&hl=en&zoom=1&tid=]
# Number of images: 54
# [Image saved as: image_output/hd9MAAAAIBAJ/1166743.jpg]
# [Running OCR]
# [Saved as: ocr_output/hd9MAAAAIBAJ-1166743_annotated_ocr.json]
# [Saved as: ocr_output/hd9MAAAAIBAJ-1166743_OCR.txt]
#
# 120 [Building images located at: https://news.google.com/newspapers?id=hd9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1177687&img=1&hl=en&zoom=1&tid=]
# Number of images: 54
# [Image saved as: image_output/hd9MAAAAIBAJ/1177687.jpg]
# [Running OCR]
# [Saved as: ocr_output/hd9MAAAAIBAJ-1177687_annotated_ocr.json]
# [Saved as: ocr_output/hd9MAAAAIBAJ-1177687_OCR.txt]
#
# 121 [Building images located at: https://news.google.com/newspapers?id=hd9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1188663&img=1&hl=en&zoom=1&tid=]
# Number of images: 54
# [Image saved as: image_output/hd9MAAAAIBAJ/1188663.jpg]
# [Running OCR]
# [Saved as: ocr_output/hd9MAAAAIBAJ-1188663_annotated_ocr.json]
# [Saved as: ocr_output/hd9MAAAAIBAJ-1188663_OCR.txt]
#
# 122 [Building images located at: https://news.google.com/newspapers?id=hd9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1199575&img=1&hl=en&zoom=1&tid=]
# Number of images: 60
# Warning! Image is not of known size.
# 123 [Building images located at: https://news.google.com/newspapers?id=hd9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1211191&img=1&hl=en&zoom=1&tid=]
# Number of images: 24
# [Image saved as: image_output/hd9MAAAAIBAJ/1211191.jpg]
# [Running OCR]
# [Saved as: ocr_output/hd9MAAAAIBAJ-

# [Saved as: ocr_output/iN9MAAAAIBAJ-1406849_OCR.txt]
#
# 142 [Building images located at: https://news.google.com/newspapers?id=iN9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=416%2C1417633&img=1&hl=en&zoom=1&tid=]
# Number of images: 30
# [Image saved as: image_output/iN9MAAAAIBAJ/1417633.jpg]
# [Running OCR]
# [Saved as: ocr_output/iN9MAAAAIBAJ-1417633_annotated_ocr.json]
# [Saved as: ocr_output/iN9MAAAAIBAJ-1417633_OCR.txt]
#
# 143 [Building images located at: https://news.google.com/newspapers?id=iN9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=32%2C1428641&img=1&hl=en&zoom=1&tid=]
# Number of images: 78
# Warning! Image is not of known size.
# 144 [Building images located at: https://news.google.com/newspapers?id=iN9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1432833&img=1&hl=en&zoom=1&tid=]
# Number of images: 30
# [Image saved as: image_output/iN9MAAAAIBAJ/1432833.jpg]
# [Running OCR]
# [Saved as: ocr_output/iN9MAAAAIBAJ-1432833_annotated_ocr.json]
# [Saved as: ocr_output/iN9MAAAAIBAJ-1432833_OCR.txt]
#
# 145 [Building images located at: https://news.google.com/newspapers?id=iN9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1443814&img=1&hl=en&zoom=1&tid=]
# Number of images: 30
# [Image saved as: image_output/iN9MAAAAIBAJ/1443814.jpg]
# [Running OCR]
# [Saved as: ocr_output/iN9MAAAAIBAJ-1443814_annotated_ocr.json]
# [Saved as: ocr_output/iN9MAAAAIBAJ-1443814_OCR.txt]
#
# 146 [Building images located at: https://news.google.com/newspapers?id=id9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1454758&img=1&hl=en&zoom=1&tid=]
# Number of images: 35
# [Image saved as: image_output/id9MAAAAIBAJ/1454758.jpg]
# [Running OCR]
# [Saved as: ocr_output/id9MAAAAIBAJ-1454758_annotated_ocr.json]
# [Saved as: ocr_output/id9MAAAAIBAJ-1454758_OCR.txt]
#
# 147 [Building images located at: https://news.google.com/newspapers?id=id9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1465734&img=1&hl=en&zoom=1&tid=]
# Number of images: 35
# [Image saved as: image_output/id9MAAAAIBAJ/1465734.jpg]
# [Running OCR]
# [Saved as: ocr_output/id9MAAAAIBAJ-1465734_annotated_ocr.json]
# [Saved as: ocr_output/id9MAAAAIBAJ-1465734_OCR.txt]
#
# 148 [Building images located at: https://news.google.com/newspapers?id=id9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1476678&img=1&hl=en&zoom=1&tid=]
# Number of images: 35
# [Image saved as: image_output/id9MAAAAIBAJ/1476678.jpg]
# [Running OCR]
# [Saved as: ocr_output/id9MAAAAIBAJ-1476678_annotated_ocr.json]
# [Saved as: ocr_output/id9MAAAAIBAJ-1476678_OCR.txt]
#
# 149 [Building images located at: https://news.google.com/newspapers?id=id9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1487686&img=1&hl=en&zoom=1&tid=]
# Number of images: 35
# [Image saved as: image_output/id9MAAAAIBAJ/1487686.jpg]
# [Running OCR]
# [Saved as: ocr_output/id9MAAAAIBAJ-1487686_annotated_ocr.json]
# [Saved as: ocr_output/id9MAAAAIBAJ-1487686_OCR.txt]
#
# 150 [Building images located at: https://news.google.com/newspapers?id=id9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1498598&img=1&hl=en&zoom=1&tid=]
# Number of images: 35
# [Image saved as: image_output/id9MAAAAIBAJ/1498598.jpg]
# [Running OCR]
# [Saved as: ocr_output/id9MAAAAIBAJ-1498598_annotated_ocr.json]
# [Saved as: ocr_output/id9MAAAAIBAJ-1498598_OCR.txt]
#
# 151 [Building images located at: https://news.google.com/newspapers?id=id9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1509638&img=1&hl=en&zoom=1&tid=]
# Number of images: 35
# [Image saved as: image_output/id9MAAAAIBAJ/1509638.jpg]
# [Running OCR]
# [Saved as: ocr_output/id9MAAAAIBAJ-1509638_annotated_ocr.json]
# [Saved as: ocr_output/id9MAAAAIBAJ-1509638_OCR.txt]
#
# 152 [Building images located at: https://news.google.com/newspapers?id=id9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1520491&img=1&hl=en&zoom=1&tid=]
# Number of images: 35
# [Image saved as: image_output/id9MAAAAIBAJ/1520491.jpg]
# [Running OCR]
# [Saved as: ocr_output/id9MAAAAIBAJ-1520491_annotated_ocr.json]
# [Saved as: ocr_output/id9MAAAAIBAJ-1520491_OCR.txt]
#
# 153 [Building images located at: https://news.google.com/newspapers?id=id9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1531494&img=1&hl=en&zoom=1&tid=]
# Number of images: 35
# [Image saved as: image_output/id9MAAAAIBAJ/1531494.jpg]
# [Running OCR]
# [Saved as: ocr_output/id9MAAAAIBAJ-1531494_annotated_ocr.json]
# [Saved as: ocr_output/id9MAAAAIBAJ-1531494_OCR.txt]
#
# 154 [Building images located at: https://news.google.com/newspapers?id=id9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1542443&img=1&hl=en&zoom=1&tid=]
# Number of images: 35
# [Image saved as: image_output/id9MAAAAIBAJ/1542443.jpg]
# [Running OCR]
# [Saved as: ocr_output/id9MAAAAIBAJ-1542443_annotated_ocr.json]
# [Saved as: ocr_output/id9MAAAAIBAJ-1542443_OCR.txt]
#
# 155 [Building images located at: https://news.google.com/newspapers?id=id9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=256%2C1553419&img=1&hl=en&zoom=1&tid=]
# Number of images: 35
# [Image saved as: image_output/id9MAAAAIBAJ/1553419.jpg]
# [Running OCR]
# [Saved as: ocr_output/id9MAAAAIBAJ-1553419_annotated_ocr.json]
# [Saved as: ocr_output/id9MAAAAIBAJ-1553419_OCR.txt]
#
# 156 [Building images located at: https://news.google.com/newspapers?id=id9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1564331&img=1&hl=en&zoom=1&tid=]
# Number of images: 35
# [Image saved as: image_output/id9MAAAAIBAJ/1564331.jpg]
# [Running OCR]
# [Saved as: ocr_output/id9MAAAAIBAJ-1564331_annotated_ocr.json]
# [Saved as: ocr_output/id9MAAAAIBAJ-1564331_OCR.txt]
#
# 157 [Building images located at: https://news.google.com/newspapers?id=id9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1575275&img=1&hl=en&zoom=1&tid=]
# Number of images: 35
# [Image saved as: image_output/id9MAAAAIBAJ/1575275.jpg]
# [Running OCR]
# [Saved as: ocr_output/id9MAAAAIBAJ-1575275_annotated_ocr.json]
# [Saved as: ocr_output/id9MAAAAIBAJ-1575275_OCR.txt]
#
# 158 [Building images located at: https://news.google.com/newspapers?id=id9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1586475&img=1&hl=en&zoom=1&tid=]
# Number of images: 35
# [Image saved as: image_output/id9MAAAAIBAJ/1586475.jpg]
# [Running OCR]
# [Saved as: ocr_output/id9MAAAAIBAJ-1586475_annotated_ocr.json]
# [Saved as: ocr_output/id9MAAAAIBAJ-1586475_OCR.txt]
#
# 159 [Building images located at: https://news.google.com/newspapers?id=id9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1597387&img=1&hl=en&zoom=1&tid=]
# Number of images: 35
# [Image saved as: image_output/id9MAAAAIBAJ/1597387.jpg]
# [Running OCR]
# [Saved as: ocr_output/id9MAAAAIBAJ-1597387_annotated_ocr.json]
# [Saved as: ocr_output/id9MAAAAIBAJ-1597387_OCR.txt]
#
# 160 [Building images located at: https://news.google.com/newspapers?id=id9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1608235&img=1&hl=en&zoom=1&tid=]
# Number of images: 35
# [Image saved as: image_output/id9MAAAAIBAJ/1608235.jpg]
# [Running OCR]
# [Saved as: ocr_output/id9MAAAAIBAJ-1608235_annotated_ocr.json]
# [Saved as: ocr_output/id9MAAAAIBAJ-1608235_OCR.txt]
#
# 161 [Building images located at: https://news.google.com/newspapers?id=id9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1619216&img=1&hl=en&zoom=1&tid=]
# Number of images: 35
# [Image saved as: image_output/id9MAAAAIBAJ/1619216.jpg]
# [Running OCR]
# [Saved as: ocr_output/id9MAAAAIBAJ-1619216_annotated_ocr.json]
# [Saved as: ocr_output/id9MAAAAIBAJ-1619216_OCR.txt]
#
# 162 [Building images located at: https://news.google.com/newspapers?id=id9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1630219&img=1&hl=en&zoom=1&tid=]
# Number of images: 35
# [Image saved as: image_output/id9MAAAAIBAJ/1630219.jpg]
# [Running OCR]
# [Saved as: ocr_output/id9MAAAAIBAJ-1630219_annotated_ocr.json]
# [Saved as: ocr_output/id9MAAAAIBAJ-1630219_OCR.txt]
#
# 163 [Building images located at: https://news.google.com/newspapers?id=id9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1641227&img=1&hl=en&zoom=1&tid=]
# Number of images: 35
# [Image saved as: image_output/id9MAAAAIBAJ/1641227.jpg]
# [Running OCR]
# [Saved as: ocr_output/id9MAAAAIBAJ-1641227_annotated_ocr.json]
# [Saved as: ocr_output/id9MAAAAIBAJ-1641227_OCR.txt]
#
# 164 [Building images located at: https://news.google.com/newspapers?id=it9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1652240&img=1&hl=en&zoom=1&tid=]
# Number of images: 24
# [Image saved as: image_output/it9MAAAAIBAJ/1652240.jpg]
# [Running OCR]
# [Saved as: ocr_output/it9MAAAAIBAJ-1652240_annotated_ocr.json]
# [Saved as: ocr_output/it9MAAAAIBAJ-1652240_OCR.txt]
#
# 165 [Building images located at: https://news.google.com/newspapers?id=it9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=320%2C1663216&img=1&hl=en&zoom=1&tid=]
# Number of images: 30
# [Image saved as: image_output/it9MAAAAIBAJ/1663216.jpg]
# [Running OCR]
# [Saved as: ocr_output/it9MAAAAIBAJ-1663216_annotated_ocr.json]
# [Saved as: ocr_output/it9MAAAAIBAJ-1663216_OCR.txt]
#
# 166 [Building images located at: https://news.google.com/newspapers?id=it9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1674192&img=1&hl=en&zoom=1&tid=]
# Number of images: 30
# [Image saved as: image_output/it9MAAAAIBAJ/1674192.jpg]
# [Running OCR]
# [Saved as: ocr_output/it9MAAAAIBAJ-1674192_annotated_ocr.json]
# [Saved as: ocr_output/it9MAAAAIBAJ-1674192_OCR.txt]
#
# 167 [Building images located at: https://news.google.com/newspapers?id=it9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1685136&img=1&hl=en&zoom=1&tid=]
# Number of images: 30
# [Image saved as: image_output/it9MAAAAIBAJ/1685136.jpg]
# [Running OCR]
# [Saved as: ocr_output/it9MAAAAIBAJ-1685136_annotated_ocr.json]
# [Saved as: ocr_output/it9MAAAAIBAJ-1685136_OCR.txt]
#
# 168 [Building images located at: https://news.google.com/newspapers?id=it9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1696176&img=1&hl=en&zoom=1&tid=]
# Number of images: 24
# [Image saved as: image_output/it9MAAAAIBAJ/1696176.jpg]
# [Running OCR]
# [Saved as: ocr_output/it9MAAAAIBAJ-1696176_annotated_ocr.json]
# [Saved as: ocr_output/it9MAAAAIBAJ-1696176_OCR.txt]
#
# 169 [Building images located at: https://news.google.com/newspapers?id=i99MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1707152&img=1&hl=en&zoom=1&tid=]
# Number of images: 35
# [Image saved as: image_output/i99MAAAAIBAJ/1707152.jpg]
# [Running OCR]
# [Saved as: ocr_output/i99MAAAAIBAJ-1707152_annotated_ocr.json]
# [Saved as: ocr_output/i99MAAAAIBAJ-1707152_OCR.txt]
#
# 170 [Building images located at: https://news.google.com/newspapers?id=i99MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1718128&img=1&hl=en&zoom=1&tid=]
# Number of images: 35
# [Image saved as: image_output/i99MAAAAIBAJ/1718128.jpg]
# [Running OCR]
# [Saved as: ocr_output/i99MAAAAIBAJ-1718128_annotated_ocr.json]
# [Saved as: ocr_output/i99MAAAAIBAJ-1718128_OCR.txt]
#
# 171 [Building images located at: https://news.google.com/newspapers?id=i99MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1729104&img=1&hl=en&zoom=1&tid=]
# Number of images: 35
# [Image saved as: image_output/i99MAAAAIBAJ/1729104.jpg]
# [Running OCR]
# [Saved as: ocr_output/i99MAAAAIBAJ-1729104_annotated_ocr.json]
# [Saved as: ocr_output/i99MAAAAIBAJ-1729104_OCR.txt]
#
# 172 [Building images located at: https://news.google.com/newspapers?id=i99MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=320%2C1740080&img=1&hl=en&zoom=1&tid=]
# Number of images: 35
# [Image saved as: image_output/i99MAAAAIBAJ/1740080.jpg]
# [Running OCR]
# [Saved as: ocr_output/i99MAAAAIBAJ-1740080_annotated_ocr.json]
# [Saved as: ocr_output/i99MAAAAIBAJ-1740080_OCR.txt]
#
# 173 [Building images located at: https://news.google.com/newspapers?id=i99MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1751093&img=1&hl=en&zoom=1&tid=]
# Number of images: 35
# [Image saved as: image_output/i99MAAAAIBAJ/1751093.jpg]
# [Running OCR]
# [Saved as: ocr_output/i99MAAAAIBAJ-1751093_annotated_ocr.json]
# [Saved as: ocr_output/i99MAAAAIBAJ-1751093_OCR.txt]
#
# 174 [Building images located at: https://news.google.com/newspapers?id=i99MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1762037&img=1&hl=en&zoom=1&tid=]
# Number of images: 35
# [Image saved as: image_output/i99MAAAAIBAJ/1762037.jpg]
# [Running OCR]
# [Saved as: ocr_output/i99MAAAAIBAJ-1762037_annotated_ocr.json]
# [Saved as: ocr_output/i99MAAAAIBAJ-1762037_OCR.txt]
#
# 175 [Building images located at: https://news.google.com/newspapers?id=i99MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1773077&img=1&hl=en&zoom=1&tid=]
# Number of images: 77
# Warning! Image is not of known size.
# 176 [Building images located at: https://news.google.com/newspapers?id=i99MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1784021&img=1&hl=en&zoom=1&tid=]
# Number of images: 77
# Warning! Image is not of known size.
# 177 [Building images located at: https://news.google.com/newspapers?id=i99MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C1795029&img=1&hl=en&zoom=1&tid=]
# Number of images: 77
# Warning! Image is not of known size.
# 178 [Building images located at: https://news.google.com/newspapers?id=i99MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg
img=1&hl=en&zoom=1&tid=]
# Number of images: 54
# [Image saved as: image_output/kN9MAAAAIBAJ/2061508.jpg]
# [Running OCR]
# [Saved as: ocr_output/kN9MAAAAIBAJ-2061508_annotated_ocr.json]
# [Saved as: ocr_output/kN9MAAAAIBAJ-2061508_OCR.txt]
#
# 201 [Building images located at: https://news.google.com/newspapers?id=kN9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=320%2C2072676&img=1&hl=en&zoom=1&tid=]
# Number of images: 54
# [Image saved as: image_output/kN9MAAAAIBAJ/2072676.jpg]
# [Running OCR]
# [Saved as: ocr_output/kN9MAAAAIBAJ-2072676_annotated_ocr.json]
# [Saved as: ocr_output/kN9MAAAAIBAJ-2072676_OCR.txt]
#
# 202 [Building images located at: https://news.google.com/newspapers?id=kd9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C2083652&img=1&hl=en&zoom=1&tid=]
# Number of images: 54
# [Image saved as: image_output/kd9MAAAAIBAJ/2083652.jpg]
# [Running OCR]
# [Saved as: ocr_output/kd9MAAAAIBAJ-2083652_annotated_ocr.json]
# [Saved as: ocr_output/kd9MAAAAIBAJ-2083652_OCR.txt]
#
# 203 [Building images located at: https://news.google.com/newspapers?id=kd9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=320%2C2094660&img=1&hl=en&zoom=1&tid=]
# Number of images: 54
# [Image saved as: image_output/kd9MAAAAIBAJ/2094660.jpg]
# [Running OCR]
# [Saved as: ocr_output/kd9MAAAAIBAJ-2094660_annotated_ocr.json]
# [Saved as: ocr_output/kd9MAAAAIBAJ-2094660_OCR.txt]
#
# 204 [Building images located at: https://news.google.com/newspapers?id=kt9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C2105673&img=1&hl=en&zoom=1&tid=]
# Number of images: 54
# [Image saved as: image_output/kt9MAAAAIBAJ/2105673.jpg]
# [Running OCR]
# [Saved as: ocr_output/kt9MAAAAIBAJ-2105673_annotated_ocr.json]
# [Saved as: ocr_output/kt9MAAAAIBAJ-2105673_OCR.txt]
#
# 205 [Building images located at: https://news.google.com/newspapers?id=kt9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C2116649&img=1&hl=en&zoom=1&tid=]
# Number of images: 54
# [Image saved as: image_output/kt9MAAAAIBAJ/2116649.jpg]
# [Running OCR]
# [Saved as: ocr_output/kt9MAAAAIBAJ-2116649_annotated_ocr.json]
# [Saved as: ocr_output/kt9MAAAAIBAJ-2116649_OCR.txt]
#
# 206 [Building images located at: https://news.google.com/newspapers?id=kt9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C2127684&img=1&hl=en&zoom=1&tid=]
# Number of images: 54
# [Image saved as: image_output/kt9MAAAAIBAJ/2127684.jpg]
# [Running OCR]
# [Saved as: ocr_output/kt9MAAAAIBAJ-2127684_annotated_ocr.json]
# [Saved as: ocr_output/kt9MAAAAIBAJ-2127684_OCR.txt]
#
# 207 [Building images located at: https://news.google.com/newspapers?id=k99MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C2138532&img=1&hl=en&zoom=1&tid=]
# Number of images: 54
# [Image saved as: image_output/k99MAAAAIBAJ/2138532.jpg]
# [Running OCR]
# [Saved as: ocr_output/k99MAAAAIBAJ-2138532_annotated_ocr.json]
# [Saved as: ocr_output/k99MAAAAIBAJ-2138532_OCR.txt]
#
# 208 [Building images located at: https://news.google.com/newspapers?id=k99MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=256%2C2149668&img=1&hl=en&zoom=1&tid=]
# Number of images: 54
# [Image saved as: image_output/k99MAAAAIBAJ/2149668.jpg]
# [Running OCR]
# [Saved as: ocr_output/k99MAAAAIBAJ-2149668_annotated_ocr.json]
# [Saved as: ocr_output/k99MAAAAIBAJ-2149668_OCR.txt]
#
# 209 [Building images located at: https://news.google.com/newspapers?id=k99MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=32%2C2160457&img=1&hl=en&zoom=1&tid=]
# Number of images: 48
# [Image saved as: image_output/k99MAAAAIBAJ/2160457.jpg]
# [Running OCR]
# [Saved as: ocr_output/k99MAAAAIBAJ-2160457_annotated_ocr.json]
# [Saved as: ocr_output/k99MAAAAIBAJ-2160457_OCR.txt]
#
# 210 [Building images located at: https://news.google.com/newspapers?id=lN9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C2170793&img=1&hl=en&zoom=1&tid=]
# Number of images: 54
# [Image saved as: image_output/lN9MAAAAIBAJ/2170793.jpg]
# [Running OCR]
# [Saved as: ocr_output/lN9MAAAAIBAJ-2170793_annotated_ocr.json]
# [Saved as: ocr_output/lN9MAAAAIBAJ-2170793_OCR.txt]
#
# 211 [Building images located at: https://news.google.com/newspapers?id=lN9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=288%2C2181769&img=1&hl=en&zoom=1&tid=]
# Number of images: 54
# [Image saved as: image_output/lN9MAAAAIBAJ/2181769.jpg]
# [Running OCR]
# [Saved as: ocr_output/lN9MAAAAIBAJ-2181769_annotated_ocr.json]
# [Saved as: ocr_output/lN9MAAAAIBAJ-2181769_OCR.txt]
#
# 212 [Building images located at: https://news.google.com/newspapers?id=lN9MAAAAIBAJ&sjid=dzUDAAAAIBAJ&pg=320%2C2192809&img=1&hl=en&zoom=1&tid=]
# Number of images: 54
# [Image saved as: image_output/lN9MAAAAIBAJ/2192809.jpg]
# [Running OCR]
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      56         try:
# ---> 57             return callable_(*args, **kwargs)
#      58         except grpc.RpcError as exc:
#
# /opt/anaconda3/lib/python3.7/site-packages/grpc/_channel.py in __call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     825                                       wait_for_ready, compression)
# --> 826         return _end_unary_response_blocking(state, call, False, None)
#     827
#
# /opt/anaconda3/lib/python3.7/site-packages/grpc/_channel.py in _end_unary_response_blocking(state, call, with_call, deadline)
#     728     else:
# --> 729         raise _InactiveRpcError(state)
#     730
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1617308168.696975841","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3941,"referenced_errors":[{"created":"@1617308168.696965354","description":"failed to connect to all addresses","file":"src/core/ext/filters/client_channel/lb_policy/pick_first/pick_first.cc","file_line":393,"grpc_status":14}]}"
# >
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# <ipython-input-1456-ac1725a512de> in <module>
#       3                17840101,
#       4                17990901,
# ----> 5                'RoyalStJohnGazette')
#       6
#       7 # Run this second - Quebec Gazette
#
# <ipython-input-1455-1de120d6d7b8> in get_newspapers(url, start_date, end_date, folder_name)
#      17
#      18         # Collect OCR data
# ---> 19         get_ocr_data(list_of_imgs[i])
#      20
#      21         # Log completed image
#
# <ipython-input-1454-0ac78dfd3a6a> in get_ocr_data(url)
#      18
#      19         image = vision.types.Image(content = content)
# ---> 20         response = client.text_detection(image = image)
#      21         texts = response.text_annotations
#      22
#
# /opt/anaconda3/lib/python3.7/site-packages/google/cloud/vision_helpers/decorators.py in inner(self, image, max_results, retry, timeout, **kwargs)
#      99             copied_features["max_results"] = max_results
#     100         request = dict(image=image, features=[copied_features], **kwargs)
# --> 101         response = self.annotate_image(request, retry=retry, timeout=timeout)
#     102         return response
#     103
#
# /opt/anaconda3/lib/python3.7/site-packages/google/cloud/vision_helpers/__init__.py in annotate_image(self, request, retry, timeout)
#      70         # of them.
#      71         protobuf.setdefault(request, "features", self._get_all_features())
# ---> 72         r = self.batch_annotate_images([request], retry=retry, timeout=timeout)
#      73         return r.responses[0]
#      74
#
# /opt/anaconda3/lib/python3.7/site-packages/google/cloud/vision_v1/gapic/image_annotator_client.py in batch_annotate_images(self, requests, parent, retry, timeout, metadata)
#     272
#     273         return self._inner_api_calls["batch_annotate_images"](
# --> 274             request, retry=retry, timeout=timeout, metadata=metadata
#     275         )
#     276
#
# /opt/anaconda3/lib/python3.7/site-packages/google/api_core/gapic_v1/method.py in __call__(self, *args, **kwargs)
#     141             kwargs["metadata"] = metadata
#     142
# --> 143         return wrapped_func(*args, **kwargs)
#     144
#     145
#
# /opt/anaconda3/lib/python3.7/site-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      57             return callable_(*args, **kwargs)
#      58         except grpc.RpcError as exc:
# ---> 59             six.raise_from(exceptions.from_grpc_error(exc), exc)
#      60
#      61     return error_remapped_callable
#
# /opt/anaconda3/lib/python3.7/site-packages/six.py in raise_from(value, from_value)
#
# ServiceUnavailable: 503 failed to connect to all addresses
